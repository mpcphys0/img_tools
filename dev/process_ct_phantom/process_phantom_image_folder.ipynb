# %%
import sys

# %%
# enter path to folder containing ctfunctions.py so this notebook can import it:
ctfunctions_path = r"C:\Users\M305747\OneDrive - Mayo Clinic\MPC\python-scripts\mpc\process_ct_phantom"
sys.path.insert(1, ctfunctions_path)

# %%
import ctfunctions
ctfunctions.test_print()
# Out:
# ctfunctions.py connected and working 😎

# %%
# %%capture
### If you are making changes to ctfunctions.py, reload the package for those changes to take effect:
# import importlib
# importlib.reload(ctfunctions)

# %%
# %%capture
# Enter image_folder_path: path to folder containing only uncompressed DICOM images of the gammex 464 phantom,
# at least covering position 0 through position 120. The program searches for 0 and 120 BBs for positioning.
# Enter reports folder path for placing generated HTML and CSV reports.
# Images must have at least Slice Location, Slice Thickness, Rescale Intercept, Rescale Slope, and Pixel Spacing in the header

image_folder_path = r"C:\Users\M305747\Desktop\Test\Unzipped\jax_ct_phantom\2023-11-07-001\IMAGES"
reports_folder_path = r"C:\Users\M305747\Desktop\Test\Unzipped\jax_ct_phantom\2023-11-07-001\reports"
ctfunctions.process_single_series_folder(image_folder_path, reports_folder_path)
# Out:
# ## ACR CT Phantom Analysis Report
# <style type="text/css">
# #T_3a183_row0_col0, #T_3a183_row0_col1, #T_3a183_row1_col0, #T_3a183_row1_col1, #T_3a183_row2_col0, #T_3a183_row2_col1, #T_3a183_row3_col0, #T_3a183_row3_col1, #T_3a183_row4_col0, #T_3a183_row4_col1, #T_3a183_row5_col0, #T_3a183_row5_col1, #T_3a183_row6_col0, #T_3a183_row6_col1, #T_3a183_row7_col0, #T_3a183_row7_col1, #T_3a183_row8_col0, #T_3a183_row8_col1, #T_3a183_row9_col0, #T_3a183_row9_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_3a183">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3a183_row0_col0" class="data row0 col0" >Study Date</td>
#       <td id="T_3a183_row0_col1" class="data row0 col1" >2023-10-10</td>
#     </tr>
#     <tr>
#       <td id="T_3a183_row1_col0" class="data row1 col0" >Manufacturer</td>
#       <td id="T_3a183_row1_col1" class="data row1 col1" >SIEMENS</td>
#     </tr>
#     <tr>
#       <td id="T_3a183_row2_col0" class="data row2 col0" >Institution Name</td>
# ...
